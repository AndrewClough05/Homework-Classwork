# %%
# Question 1
def histogram(string_list):
    string_dict = dict()

    for i in string_list:
        if i in string_dict:
            string_dict[i] += 1
        else:
            string_dict[i] = 1
            
    return string_dict

def anograms(input_string):
     with open('words.txt', 'r') as read_file: 
         with open('output.txt', 'w') as write_file: 
             for line in read_file:
                 
                line = line.strip()
         
                if histogram(input_string) == histogram(line):
                    write_file.write(line + '\n')

# %%
anograms("pots")

# %%
# Question 2
def heteropalindromes():
    with open('words.txt', 'r') as read_file: 
          W = set()
          for line in read_file:
               line = line.strip()
               W.add(line)
          for line in W:
               reverseLine = line[::-1]
               if reverseLine in W:
                    if line == reverseLine:
                         pass
                    else:
                         print(line, reverseLine)

# %%
heteropalindromes()
# Out:
# mir rim
# serif fires
# lin nil
# agenes senega
# rub bur
# mool loom
# auks skua
# slag gals
# bis sib
# ho oh
# emir rime
# reflow wolfer
# brad darb
# lit til
# buns snub
# ervil livre
# dessert tressed
# wot tow
# pool loop
# drib bird
# neep peen
# demit timed
# meed deem
# rood door
# redips spider
# lamina animal
# debut tubed
# time emit
# stub buts
# sib bis
# gnar rang
# snoop poons
# spirt trips
# depots stoped
# liard drail
# abut tuba
# too oot
# repins sniper
# mural larum
# trow wort
# etas sate
# em me
# swot tows
# rial lair
# tool loot
# stab bats
# gid dig
# drail liard
# pools sloop
# reined denier
# live evil
# brag garb
# keel leek
# steeks skeets
# pam map
# sub bus
# devas saved
# ta at
# part trap
# emit time
# mar ram
# stressed desserts
# kips spik
# avid diva
# noil lion
# cares serac
# mho ohm
# had dah
# dialer relaid
# denim mined
# bad dab
# un nu
# tip pit
# tubed debut
# pas sap
# si is
# rail liar
# doom mood
# retool looter
# evil live
# pows swop
# ...

# %% [markdown]
# Code Comments
#
# For the first problem "histogram" counts how many of each letter are the the word (string_list) by using a for loop and an if/else statement. Then using "anograms" I used a "with open" statment to look at the words from "Words.txt" and write the new program in "output.txt". Then I striped the line of any spaces and if histogram(string_list) == histogram(line) the the program would write it down in (output.txt).
#
# For the second problem I used with open so the program could view all the words in "words.txt". Then I made a set of all the words striped of spaces and called it "W" using a for loop. Then for every line in "words.txt" I created reverseLine which is line but the letters are in reverse order. And in order to not get duplicates I made an if/else statement that was if line == reverseLine then "pass" becasue I didn't want it printing words like "pop". The only thing that I couldn't figure out was how to only print them once and I was going to as it in class but since I was ill I'm going to turn it in with each heteropalindrome getting printed twice.
